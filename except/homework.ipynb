# %% [markdown]
# # 作业

# %% [markdown]
# ## 练习（exercise）
#
# 课堂或自习时完成。

# %% [markdown]
# ## 面试
#
# 自习时完成，相互交流

# %% [markdown]
# ## 作业

# %% [markdown]
# ### 创建my-except-case仓库
#
# 创建my-except-case仓库，列出所有Python内置异常。为以后添加错误案例做准备。
